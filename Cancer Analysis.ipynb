# %% [markdown]
# **BUSINESS UNDERSTANDING**
#
# We will be analyzying a data set from the World Health Organzation(WHO) concerning Cancer and the corresponding figures related to numbers diagnosed,deaths and the different commonaities between the patients.
# This analysis will help in understanding:
# *   Lethalty of different types of cancer
# *   Possible causes of cancer
# *   Prevention courses of action
# This all culminates in saving the lives of many people by finding enhancing our understanding of the disease.
# The report will entail:
#   Data Understanding
# In this step we will read the dataset and make summary reports. The summary report will provide a high level idea of the data set such as:
#
# *   Data size: number of rows and columns
# *   Data fields: number of missing values
#   Data Visualization
# This will include plotting the data to provide better insights.
#   Data Preparation
# Once we have high level idea about the dataset, its time to delve deeper and carry out some basic data preparation steps to make our dataset ready for statistical analysis and modeling.
# These are the key steps we shall be performing:
# *   Remove duplicates
# *   Get rid of missing values

# %%
#load data set
#defining the file path
#cancer=/content/Cancer.xlsx
#libraray(pandas)
import pandas as pd
#Read the excel file
cancer=pd.read_excel("/content/Cancer.xlsx")
cancer
# Out:
#     Country or Territory  \
# 0            Afghanistan
# 1                Algeria
# 2             Azerbaijan
# 3                Albania
# 4                Armenia
# ..                   ...
# 202              Réunion
# 203     French Polynesia
# 204           Guadeloupe
# 205                 Guam
# 206           Martinique
#
#     Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# 0                                                  0.5
# 1                                                  1.1
# 2                                                  3.2
# 3                                                  4.9
# 4                                                    5
# ..                                                 ...
# 202                                            No data
# 203                                            No data
# 204                                            No data
# ...

# %% [markdown]
# We have loaded the data set which is Cancer.xlsx, then defined the file path as Cancer . Then we we imported the library for the data set then we read the data.

# %%
#displaying the first few rows
cancer.head()
# Out:
#   Country or Territory  \
# 0          Afghanistan
# 1              Algeria
# 2           Azerbaijan
# 3              Albania
# 4              Armenia
#
#   Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# 0                                                0.5
# 1                                                1.1
# 2                                                3.2
# 3                                                4.9
# 4                                                  5
#
#   Smoking prevalence male\nPrevalence (%) of daily smoking for men  \
# 0                                               21.4
# 1                                               17.5
# 2                                               36.7
# 3                                               40.9
# 4                                               43.5
#
#   Smoking prevalence female\nPrevalence (%) of daily smoking for women  \
# ...

# %% [markdown]
# The first 5 rows of the data set.

# %%
#displaying the last few rows
cancer.tail()
# Out:
#     Country or Territory  \
# 202              Réunion
# 203     French Polynesia
# 204           Guadeloupe
# 205                 Guam
# 206           Martinique
#
#     Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# 202                                            No data
# 203                                            No data
# 204                                            No data
# 205                                            No data
# 206                                            No data
#
#     Smoking prevalence male\nPrevalence (%) of daily smoking for men  \
# 202                                            No data
# 203                                            No data
# 204                                            No data
# 205                                            No data
# 206                                            No data
#
# ...

# %% [markdown]
# The last rows of the data set

# %%
#data types
cancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 27 columns):
#  #   Column                                                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                                                     --------------  -----
#  0   Country or Territory                                                                                                                                       207 non-null    object
#  1   Cancer deaths attributable to alcohol
# Proportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016                       207 non-null    object
#  2   Smoking prevalence male
# ...

# %% [markdown]
# These are the data types available in the dataset

# %%
#data set description
cancer.describe()
# Out:
#        Country or Territory  \
# count                   207
# unique                  204
# top                 Lesotho
# freq                      2
#
#        Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# count                                                 207
# unique                                                 96
# top                                               No data
# freq                                                   23
#
#        Smoking prevalence male\nPrevalence (%) of daily smoking for men  \
# count                                                 207
# unique                                                145
# top                                               No data
# freq                                                   18
#
#        Smoking prevalence female\nPrevalence (%) of daily smoking for women  \
# ...

# %% [markdown]
# These is the summary statistics of the data

# %%
print(cancer.shape)
# Out:
# (207, 27)

# %% [markdown]
# The data set has 207 rows and 27 columns
